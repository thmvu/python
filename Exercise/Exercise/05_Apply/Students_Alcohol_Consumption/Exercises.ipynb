# %% [markdown]
# # Student Alcohol Consumption

# %% [markdown]
# ### Introduction:
#
# This time you will download a dataset from the UCI.
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/thieu1995/csv-files/main/data/pandas/student-mat.csv).

# %% [markdown]
# ### Step 3. Assign it to a variable called df.

# %%
df = pd.read_csv("student_alcohol.csv")

# %% [markdown]
# ### Step 4. For the purpose of this exercise slice the dataframe from 'school' until the 'guardian' column

# %%
student_data = df.loc[:, "school":"guardian"]
student_data.head()
# Out:
#   school sex  age address famsize  ... Fedu     Mjob      Fjob  reason guardian
# 0     GP   F   18       U     GT3  ...    4  at_home   teacher  course   mother
# 1     GP   F   17       U     GT3  ...    1  at_home     other  course   father
# 2     GP   F   15       U     LE3  ...    1  at_home     other   other   mother
# 3     GP   F   15       U     GT3  ...    2   health  services    home   mother
# 4     GP   F   16       U     GT3  ...    3    other     other    home   father
#
# [5 rows x 12 columns]

# %% [markdown]
# ### Step 5. Create a lambda function that will capitalize strings.

# %%
capitalizer = lambda value: value.capitalize()

# %% [markdown]
# ### Step 6. Capitalize both Mjob and Fjob

# %%
student_data["Mjob"] = student_data.Mjob.map(capitalizer)
student_data["Fjob"] = student_data.Fjob.map(capitalizer)
student_data.head()
# Out:
#   school sex  age address famsize  ... Fedu     Mjob      Fjob  reason guardian
# 0     GP   F   18       U     GT3  ...    4  At_home   Teacher  course   mother
# 1     GP   F   17       U     GT3  ...    1  At_home     Other  course   father
# 2     GP   F   15       U     LE3  ...    1  At_home     Other   other   mother
# 3     GP   F   15       U     GT3  ...    2   Health  Services    home   mother
# 4     GP   F   16       U     GT3  ...    3    Other     Other    home   father
#
# [5 rows x 12 columns]

# %% [markdown]
# ### Step 7. Print the last elements of the data set.

# %%
student_data.tail()
# Out:
#     school sex  age address famsize  ... Fedu      Mjob      Fjob  reason guardian
# 390     MS   M   20       U     LE3  ...    2  Services  Services  course    other
# 391     MS   M   17       U     LE3  ...    1  Services  Services  course   mother
# 392     MS   M   21       R     GT3  ...    1     Other     Other  course    other
# 393     MS   M   18       R     LE3  ...    2  Services     Other  course   mother
# 394     MS   M   19       U     LE3  ...    1     Other   At_home  course   father
#
# [5 rows x 12 columns]

# %% [markdown]
# ### Step 8. Did you notice the original dataframe is still lowercase? Why is that? Fix it and capitalize Mjob and Fjob.

# %%
df[["Mjob", "Fjob"]] = df[["Mjob", "Fjob"]].apply(lambda col: col.map(capitalizer))
df.head()
# Out:
#   school sex  age address famsize Pstatus  ...  Walc  health absences  G1  G2  G3
# 0     GP   F   18       U     GT3       A  ...     1       3        6   5   6   6
# 1     GP   F   17       U     GT3       T  ...     1       3        4   5   5   6
# 2     GP   F   15       U     LE3       T  ...     3       3       10   7   8  10
# 3     GP   F   15       U     GT3       T  ...     1       5        2  15  14  15
# 4     GP   F   16       U     GT3       T  ...     2       5        4   6  10  10
#
# [5 rows x 33 columns]

# %% [markdown]
# ### Step 9. Create a function called majority that returns a boolean value to a new column called legal_drinker (Consider majority as older than 17 years old)

# %%
def majority(age):
    return age > 17

# %%
df["legal_drinker"] = df.age.map(majority)
df.head()
# Out:
#   school sex  age address famsize  ... absences  G1  G2  G3 legal_drinker
# 0     GP   F   18       U     GT3  ...        6   5   6   6          True
# 1     GP   F   17       U     GT3  ...        4   5   5   6         False
# 2     GP   F   15       U     LE3  ...       10   7   8  10         False
# 3     GP   F   15       U     GT3  ...        2  15  14  15         False
# 4     GP   F   16       U     GT3  ...        4   6  10  10         False
#
# [5 rows x 34 columns]

# %% [markdown]
# ### Step 10. Multiply every number of the dataset by 10.
# ##### I know this makes no sense, don't forget it is just an exercise

# %%
from numbers import Number


def times10(value):
    return value * 10 if isinstance(value, Number) and not isinstance(value, bool) else value

# %%
df.apply(lambda col: col.map(times10))
# Out:
#     school sex  age address famsize  ... absences   G1   G2   G3 legal_drinker
# 0       GP   F  180       U     GT3  ...       60   50   60   60          True
# 1       GP   F  170       U     GT3  ...       40   50   50   60         False
# 2       GP   F  150       U     LE3  ...      100   70   80  100         False
# 3       GP   F  150       U     GT3  ...       20  150  140  150         False
# 4       GP   F  160       U     GT3  ...       40   60  100  100         False
# ..     ...  ..  ...     ...     ...  ...      ...  ...  ...  ...           ...
# 390     MS   M  200       U     LE3  ...      110   90   90   90          True
# 391     MS   M  170       U     LE3  ...       30  140  160  160         False
# 392     MS   M  210       R     GT3  ...       30  100   80   70          True
# 393     MS   M  180       R     LE3  ...        0  110  120  100          True
# 394     MS   M  190       U     LE3  ...       50   80   90   90          True
#
# [395 rows x 34 columns]
