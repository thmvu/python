# %% [markdown]
# # Wine

# %% [markdown]
# ### Introduction:
#
# This exercise is a adaptation from the UCI Wine dataset.
# The only pupose is to practice deleting data with pandas.
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://archive.ics.uci.edu/ml/machine-learning-databases/wine/wine.data).

# %% [markdown]
# ### Step 3. Assign it to a variable called wine

# %%
wine = pd.read_csv("wine.csv", header=None)

# %% [markdown]
# ### Step 4. Delete the first, fourth, seventh, nineth, eleventh, thirteenth and fourteenth columns

# %%
wine = wine.drop(columns=[0, 3, 6, 8, 10, 12, 13])
wine.head()
# Out:
#       1     2     4    5     7     9     11
# 0  14.23  1.71  15.6  127  3.06  2.29  1.04
# 1  13.20  1.78  11.2  100  2.76  1.28  1.05
# 2  13.16  2.36  18.6  101  3.24  2.81  1.03
# 3  14.37  1.95  16.8  113  3.49  2.18  0.86
# 4  13.24  2.59  21.0  118  2.69  1.82  1.04

# %% [markdown]
# ### Step 5. Assign the columns as below:
#
# The attributes are (donated by Riccardo Leardi, riclea '@' anchem.unige.it):
# 1) alcohol
# 2) malic_acid
# 3) alcalinity_of_ash
# 4) magnesium
# 5) flavanoids
# 6) proanthocyanins
# 7) hue

# %%
wine.columns = [
    "alcohol",
    "malic_acid",
    "alcalinity_of_ash",
    "magnesium",
    "flavanoids",
    "proanthocyanins",
    "hue",
]
wine.head()
# Out:
#    alcohol  malic_acid  alcalinity_of_ash  ...  flavanoids  proanthocyanins   hue
# 0    14.23        1.71               15.6  ...        3.06             2.29  1.04
# 1    13.20        1.78               11.2  ...        2.76             1.28  1.05
# 2    13.16        2.36               18.6  ...        3.24             2.81  1.03
# 3    14.37        1.95               16.8  ...        3.49             2.18  0.86
# 4    13.24        2.59               21.0  ...        2.69             1.82  1.04
#
# [5 rows x 7 columns]

# %% [markdown]
# ### Step 6. Set the values of the first 3 rows from alcohol as NaN

# %%
wine.loc[:2, "alcohol"] = np.nan
wine.head()
# Out:
#    alcohol  malic_acid  alcalinity_of_ash  ...  flavanoids  proanthocyanins   hue
# 0      NaN        1.71               15.6  ...        3.06             2.29  1.04
# 1      NaN        1.78               11.2  ...        2.76             1.28  1.05
# 2      NaN        2.36               18.6  ...        3.24             2.81  1.03
# 3    14.37        1.95               16.8  ...        3.49             2.18  0.86
# 4    13.24        2.59               21.0  ...        2.69             1.82  1.04
#
# [5 rows x 7 columns]

# %% [markdown]
# ### Step 7. Now set the value of the rows 3 and 4 of magnesium as NaN

# %%
wine.loc[3:4, "magnesium"] = np.nan
wine.head()
# Out:
#    alcohol  malic_acid  alcalinity_of_ash  ...  flavanoids  proanthocyanins   hue
# 0      NaN        1.71               15.6  ...        3.06             2.29  1.04
# 1      NaN        1.78               11.2  ...        2.76             1.28  1.05
# 2      NaN        2.36               18.6  ...        3.24             2.81  1.03
# 3    14.37        1.95               16.8  ...        3.49             2.18  0.86
# 4    13.24        2.59               21.0  ...        2.69             1.82  1.04
#
# [5 rows x 7 columns]

# %% [markdown]
# ### Step 8. Fill the value of NaN with the number 10 in alcohol and 100 in magnesium

# %%
wine.alcohol = wine.alcohol.fillna(10)
wine.magnesium = wine.magnesium.fillna(100)
wine.head()
# Out:
#    alcohol  malic_acid  alcalinity_of_ash  ...  flavanoids  proanthocyanins   hue
# 0    10.00        1.71               15.6  ...        3.06             2.29  1.04
# 1    10.00        1.78               11.2  ...        2.76             1.28  1.05
# 2    10.00        2.36               18.6  ...        3.24             2.81  1.03
# 3    14.37        1.95               16.8  ...        3.49             2.18  0.86
# 4    13.24        2.59               21.0  ...        2.69             1.82  1.04
#
# [5 rows x 7 columns]

# %% [markdown]
# ### Step 9. Count the number of missing values

# %%
wine.isna().sum().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ### Step 10.  Create an array of 10 random numbers up until 10

# %%
random_numbers = np.random.randint(0, 10, 10)
random_numbers
# Out:
# array([0, 4, 4, 6, 0, 1, 8, 4, 3, 9], dtype=int32)

# %% [markdown]
# ### Step 11.  Use random numbers you generated as an index and assign NaN value to each of cell.

# %%
wine.loc[random_numbers, "alcohol"] = np.nan
wine.head(10)
# Out:
#    alcohol  malic_acid  alcalinity_of_ash  ...  flavanoids  proanthocyanins   hue
# 0      NaN        1.71               15.6  ...        3.06             2.29  1.04
# 1      NaN        1.78               11.2  ...        2.76             1.28  1.05
# 2    10.00        2.36               18.6  ...        3.24             2.81  1.03
# 3      NaN        1.95               16.8  ...        3.49             2.18  0.86
# 4      NaN        2.59               21.0  ...        2.69             1.82  1.04
# 5    14.20        1.76               15.2  ...        3.39             1.97  1.05
# 6      NaN        1.87               14.6  ...        2.52             1.98  1.02
# 7    14.06        2.15               17.6  ...        2.51             1.25  1.06
# 8      NaN        1.64               14.0  ...        2.98             1.98  1.08
# 9      NaN        1.35               16.0  ...        3.15             1.85  1.01
#
# [10 rows x 7 columns]

# %% [markdown]
# ### Step 12.  How many missing values do we have?

# %%
wine.isna().sum().sum()
# Out:
# np.int64(7)

# %% [markdown]
# ### Step 13. Delete the rows that contain missing values

# %%
wine = wine.dropna()
wine.head()
# Out:
#     alcohol  malic_acid  alcalinity_of_ash  ...  flavanoids  proanthocyanins   hue
# 2     10.00        2.36               18.6  ...        3.24             2.81  1.03
# 5     14.20        1.76               15.2  ...        3.39             1.97  1.05
# 7     14.06        2.15               17.6  ...        2.51             1.25  1.06
# 10    14.10        2.16               18.0  ...        3.32             2.38  1.25
# 11    14.12        1.48               16.8  ...        2.43             1.57  1.17
#
# [5 rows x 7 columns]

# %% [markdown]
# ### Step 14. Print only the non-null values in alcohol

# %%
wine.alcohol.notna()
# Out:
# 2      True
# 5      True
# 7      True
# 10     True
# 11     True
#        ...
# 173    True
# 174    True
# 175    True
# 176    True
# 177    True
# Name: alcohol, Length: 171, dtype: bool

# %%
wine.loc[wine.alcohol.notna(), "alcohol"]
# Out:
# 2      10.00
# 5      14.20
# 7      14.06
# 10     14.10
# 11     14.12
#        ...
# 173    13.71
# 174    13.40
# 175    13.27
# 176    13.17
# 177    14.13
# Name: alcohol, Length: 171, dtype: float64

# %% [markdown]
# ### Step 15.  Reset the index, so it starts with 0 again

# %%
wine = wine.reset_index(drop=True)
wine.head()
# Out:
#    alcohol  malic_acid  alcalinity_of_ash  ...  flavanoids  proanthocyanins   hue
# 0    10.00        2.36               18.6  ...        3.24             2.81  1.03
# 1    14.20        1.76               15.2  ...        3.39             1.97  1.05
# 2    14.06        2.15               17.6  ...        2.51             1.25  1.06
# 3    14.10        2.16               18.0  ...        3.32             2.38  1.25
# 4    14.12        1.48               16.8  ...        2.43             1.57  1.17
#
# [5 rows x 7 columns]

# %% [markdown]
# ### BONUS: Create your own question and answer it.

# %%
wine.describe()
# Out:
#           alcohol  malic_acid  ...  proanthocyanins         hue
# count  171.000000  171.000000  ...       171.000000  171.000000
# mean    12.940526    2.356608  ...         1.577778    0.955123
# std      0.824320    1.133028  ...         0.577010    0.232544
# min     10.000000    0.740000  ...         0.410000    0.480000
# 25%     12.330000    1.595000  ...         1.230000    0.775000
# 50%     12.960000    1.870000  ...         1.540000    0.960000
# 75%     13.625000    3.145000  ...         1.935000    1.120000
# max     14.750000    5.800000  ...         3.580000    1.710000
#
# [8 rows x 7 columns]
